# %% [markdown]
# # Data Preprocessing for HANNA dataset

# %%
# %%HTML
# <style>
#     body{
#  --vscode-font-family: "ComicShannsMono Nerd Font";
#     }
# </style>
# Out:
# <style>
#     body{
#  --vscode-font-family: "ComicShannsMono Nerd Font";
#     }
# </style>

# %% [markdown]
# ## Import Libraries

# %%
import os
import json
import time
import nltk
import numpy as np
import pandas as pd

from tqdm.notebook import tqdm
from nltk.tokenize import sent_tokenize

# %% [markdown]
# ## Load Stories

# %% [markdown]
# 96 story prompts are provided in the dataset. Human and 6 different LLM models listed below are asked to generate stories based on these prompts.
# * Llama-7b
# * Mistral-7b
# * Beluga-13b
# * OrcaPlatypus-13b
# * LlamaInstruct-30b
# * Platypus2-70b

# %%
story_path = '../data/hanna_llm_stories.csv'
raw_story_df = pd.read_csv(story_path)
raw_story_df = raw_story_df.drop(columns=['Unnamed: 0'])

raw_story_df.head()
# Out:
#                                               Prompt  \
# 0  When you die the afterlife is an arena where y...
# 1  A new law is enacted that erases soldiers memo...
# 2  A scientific study proves that all humans have...
# 3  Write a story about an elderly wizard and his ...
# 4        You have become death, destroyer of worlds.
#
#                                                Human  \
# 0  3,000 years have I been fighting. Every mornin...
# 1  “Dad, you 're on TV again !” I heard Eric 's v...
# 2  When Tyler entered the ward, his daughter Vale...
# 3  His body was failing. He had taken care of it ...
# 4  I saw the button. It was simple, red, no words...
#
#                                                Story     Model
# 0   Great! Let's get started. How would you like ...  Llama-7b
# 1   Sure, here is a story based on the prompt:\n\...  Llama-7b
# 2   Interesting! What kind of strange behaviors a...  Llama-7b
# 3   Sure! Here is a story based on the prompt you...  Llama-7b
# 4   Hello! I'm here to help you with your story. ...  Llama-7b

# %%
human_story_df = raw_story_df[raw_story_df['Model'] == 'Llama-7b'].reset_index(drop=True)
human_story_df['Model'] = 'Human'
human_story_df['Story'] = human_story_df['Human']
human_story_df = human_story_df.drop(columns=['Human'])

human_story_df
# Out:
#                                                Prompt  \
# 0   When you die the afterlife is an arena where y...
# 1   A new law is enacted that erases soldiers memo...
# 2   A scientific study proves that all humans have...
# 3   Write a story about an elderly wizard and his ...
# 4         You have become death, destroyer of worlds.
# ..                                                ...
# 91                  All you hear is a dripping noise.
# 92  Google search engine always was alive. They re...
# 93                                      Heart of Eden
# 94  When a new president is elected, they are give...
# 95  You discover a grand hall filled with legendar...
#
#                                                 Story  Model
# 0   3,000 years have I been fighting. Every mornin...  Human
# 1   “Dad, you 're on TV again !” I heard Eric 's v...  Human
# 2   When Tyler entered the ward, his daughter Vale...  Human
# 3   His body was failing. He had taken care of it ...  Human
# 4   I saw the button. It was simple, red, no words...  Human
# ..                                                ...    ...
# 91  All I hear is a dripping noise. At first it wa...  Human
# 92  86388: *what am i* 86389: They ask me question...  Human
# 93  If everything went perfectly right, her creati...  Human
# 94  “Mr President I want you to know I am telling ...  Human
# 95  Waking with a start, my blankets strewn wildly...  Human
#
# [96 rows x 3 columns]

# %%
model_df = raw_story_df.drop(columns=['Human'])

model_df
# Out:
#                                                 Prompt  \
# 0    When you die the afterlife is an arena where y...
# 1    A new law is enacted that erases soldiers memo...
# 2    A scientific study proves that all humans have...
# 3    Write a story about an elderly wizard and his ...
# 4          You have become death, destroyer of worlds.
# ..                                                 ...
# 571                  All you hear is a dripping noise.
# 572  Google search engine always was alive. They re...
# 573                                      Heart of Eden
# 574  When a new president is elected, they are give...
# 575  You discover a grand hall filled with legendar...
#
#                                                  Story          Model
# 0     Great! Let's get started. How would you like ...       Llama-7b
# 1     Sure, here is a story based on the prompt:\n\...       Llama-7b
# 2     Interesting! What kind of strange behaviors a...       Llama-7b
# 3     Sure! Here is a story based on the prompt you...       Llama-7b
# 4     Hello! I'm here to help you with your story. ...       Llama-7b
# ..                                                 ...            ...
# 571  \nThe small, cramped room had a musty smell, a...  Platypus2-70b
# 572  \nIt was a regular day for the Google search e...  Platypus2-70b
# 573  \nIn the middle of a dense jungle, there was a...  Platypus2-70b
# 574  \nTitle: President's First Briefing\n\nThe new...  Platypus2-70b
# 575  \nAs I walked through the grand hall, filled w...  Platypus2-70b
#
# [576 rows x 3 columns]

# %% [markdown]
# Add column `Length` to the dataframe

# %%
human_story_df['Length'] = human_story_df['Story'].apply(lambda x: len(x))
model_df['Length'] = model_df['Story'].apply(lambda x: len(x))

human_story_df.head()
# Out:
#                                               Prompt  \
# 0  When you die the afterlife is an arena where y...
# 1  A new law is enacted that erases soldiers memo...
# 2  A scientific study proves that all humans have...
# 3  Write a story about an elderly wizard and his ...
# 4        You have become death, destroyer of worlds.
#
#                                                Story  Model  Length
# 0  3,000 years have I been fighting. Every mornin...  Human    1076
# 1  “Dad, you 're on TV again !” I heard Eric 's v...  Human    1315
# 2  When Tyler entered the ward, his daughter Vale...  Human    4420
# 3  His body was failing. He had taken care of it ...  Human    4575
# 4  I saw the button. It was simple, red, no words...  Human     842

# %%
model_df.head()
# Out:
#                                               Prompt  \
# 0  When you die the afterlife is an arena where y...
# 1  A new law is enacted that erases soldiers memo...
# 2  A scientific study proves that all humans have...
# 3  Write a story about an elderly wizard and his ...
# 4        You have become death, destroyer of worlds.
#
#                                                Story     Model  Length
# 0   Great! Let's get started. How would you like ...  Llama-7b     759
# 1   Sure, here is a story based on the prompt:\n\...  Llama-7b    2321
# 2   Interesting! What kind of strange behaviors a...  Llama-7b    1218
# 3   Sure! Here is a story based on the prompt you...  Llama-7b    3146
# 4   Hello! I'm here to help you with your story. ...  Llama-7b     432

# %% [markdown]
# ### Using NLTK to tokenize the stories

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Danny\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
human_story_df['Sentences'] = human_story_df['Story'].apply(lambda x: sent_tokenize(x))
model_df['Sentences'] = model_df['Story'].apply(lambda x: sent_tokenize(x))

human_story_df['Sentences Length'] = human_story_df['Sentences'].apply(lambda x: len(x))
model_df['Sentences Length'] = model_df['Sentences'].apply(lambda x: len(x))

human_story_df.head()
# Out:
#                                               Prompt  \
# 0  When you die the afterlife is an arena where y...
# 1  A new law is enacted that erases soldiers memo...
# 2  A scientific study proves that all humans have...
# 3  Write a story about an elderly wizard and his ...
# 4        You have become death, destroyer of worlds.
#
#                                                Story  Model  Length  \
# 0  3,000 years have I been fighting. Every mornin...  Human    1076
# 1  “Dad, you 're on TV again !” I heard Eric 's v...  Human    1315
# 2  When Tyler entered the ward, his daughter Vale...  Human    4420
# 3  His body was failing. He had taken care of it ...  Human    4575
# 4  I saw the button. It was simple, red, no words...  Human     842
#
#                                            Sentences  Sentences Length
# 0  [3,000 years have I been fighting., Every morn...                21
# 1  [“Dad, you 're on TV again !” I heard Eric 's ...                17
# 2  [When Tyler entered the ward, his daughter Val...                44
# 3  [His body was failing., He had taken care of i...                58
# 4  [I saw the button., It was simple, red, no wor...                11

# %%
model_df.head()
# Out:
#                                               Prompt  \
# 0  When you die the afterlife is an arena where y...
# 1  A new law is enacted that erases soldiers memo...
# 2  A scientific study proves that all humans have...
# 3  Write a story about an elderly wizard and his ...
# 4        You have become death, destroyer of worlds.
#
#                                                Story     Model  Length  \
# 0   Great! Let's get started. How would you like ...  Llama-7b     759
# 1   Sure, here is a story based on the prompt:\n\...  Llama-7b    2321
# 2   Interesting! What kind of strange behaviors a...  Llama-7b    1218
# 3   Sure! Here is a story based on the prompt you...  Llama-7b    3146
# 4   Hello! I'm here to help you with your story. ...  Llama-7b     432
#
#                                            Sentences  Sentences Length
# 0  [ Great!, Let's get started., How would you li...                12
# 1  [ Sure, here is a story based on the prompt:\n...                24
# 2  [ Interesting!, What kind of strange behaviors...                22
# 3  [ Sure!, Here is a story based on the prompt y...                34
# 4  [ Hello!, I'm here to help you with your story...                 6
